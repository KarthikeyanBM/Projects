# %% [markdown]
# <a href="https://colab.research.google.com/github/KarthikeyanBM/Projects/blob/main/IOT_domain_proj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline
sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

# %%
df = pd.read_csv("framingham.csv")
df.head()
# Out:
#    female  age  BPMeds  prevalentStroke  prevalentHyp  diabetes  totChol  \
# 0       1   39     0.0                0             0         0    195.0
# 1       0   46     0.0                0             0         0    250.0
# 2       1   48     0.0                0             0         0    245.0
# 3       0   61     0.0                0             1         0    225.0
# 4       0   46     0.0                0             0         0    285.0
#
#    sysBP  diaBP    BMI  ...  Family History  unexplained prenetal loss  \
# 0  106.0   70.0  26.97  ...               0                          0
# 1  121.0   81.0  28.73  ...               0                          0
# 2  127.5   80.0  25.34  ...               0                          0
# 3  150.0   95.0  28.58  ...               0                          0
# 4  130.0   84.0  23.10  ...               0                          0
#
#    Large Child or Birth Default  PCOS  Sys BP  Dia BP  Hemoglobin  \
# ...

# %%
pd.set_option("display.float", "{:.2f}".format)
df.describe()
# Out:
#        female     age  BPMeds  prevalentStroke  prevalentHyp  diabetes  \
# count 3525.00 3525.00 3481.00          3525.00       3525.00   3525.00
# mean     0.43   49.60    0.03             0.01          0.31      0.02
# std      0.49    8.56    0.17             0.07          0.46      0.15
# min      0.00   32.00    0.00             0.00          0.00      0.00
# 25%      0.00   42.00    0.00             0.00          0.00      0.00
# 50%      0.00   49.00    0.00             0.00          0.00      0.00
# 75%      1.00   56.00    0.00             0.00          1.00      0.00
# max      1.00   70.00    1.00             1.00          1.00      1.00
#
#        totChol   sysBP   diaBP     BMI  ...  Family History  \
# count  3483.00 3525.00 3525.00 3506.00  ...         3525.00
# mean    237.31  132.22   82.88   25.80  ...            0.50
# std      44.85   21.91   11.80    4.06  ...            0.50
# min     107.00   83.50   50.00   15.54  ...            0.00
# ...
